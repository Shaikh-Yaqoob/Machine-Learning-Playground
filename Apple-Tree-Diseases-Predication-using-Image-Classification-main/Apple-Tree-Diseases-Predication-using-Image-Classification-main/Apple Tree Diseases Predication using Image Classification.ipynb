# %% [markdown]
# ## **Project: Apple Tree Diseases Predication using Image Classification**
# > ***Given a photo of an apple leaf, can you accurately assess its health? This competition will challenge you to distinguish between leaves which are healthy, those which are infected with apple rust, those that have apple scab, and those with more than one disease.***
#
# **By : Lokesh Baviskar**
#
# **Email id : Lokeshbaviskar4@gmail.com**

# %% [markdown]
# ### Problem Statement
#
# Misdiagnosis of the many diseases impacting agricultural crops can lead to misuse of chemicals leading to the emergence of resistant pathogen strains, increased input costs, and more outbreaks with significant economic loss and environmental impacts. Current disease diagnosis based on human scouting is time-consuming and expensive, and although computer-vision based models have the promise to increase efficiency, the great variance in symptoms due to age of infected tissues, genetic variations, and light conditions within trees decreases the accuracy of detection.
#
# ### Specific Objectives
#
# Objectives of ‘Plant Pathology Challenge’ are to train a model using images of training dataset to 1) Accurately classify a given image from testing dataset into different diseased category or a healthy leaf; 2) Accurately distinguish between many diseases, sometimes more than one on a single leaf; 3) Deal with rare classes and novel symptoms; 4) Address depth perception—angle, light, shade, physiological age of the leaf; and 5) Incorporate expert knowledge in identification, annotation, quantification, and guiding computer vision to search for relevant features during learning.

# %% [markdown]
# #### Dataset Information:
#
# - image_id: the foreign key
#
# - combinations: one of the target labels
#
# - healthy: one of the target labels
#
# - rust: one of the target labels
#
# - scab: one of the target labels

# %% [markdown]
# ## Loading Data and required Libraries

# %%
import numpy as np
import pandas as pd
import os
from re import search
import shutil
import natsort
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import cv2

# %%
# !pip install natsort
# Out:
# Collecting natsort
#   Downloading natsort-8.1.0-py3-none-any.whl (37 kB)
# Installing collected packages: natsort
# Successfully installed natsort-8.1.0

# %%
dir_path = r'C:\Users\Infinity\Computer Vision Projects\Apple Tree Diseases Predication using Image Classification\images'

# %%
print('Loading Training Data Labels from CSV file')
train = pd.read_csv('train.csv')
train.head(5)
# Out:
# Loading Training Data Labels from CSV file
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0
# 3  Train_3        0                  0     1     0
# 4  Train_4        1                  0     0     0

# %% [markdown]
# #### train.csv Labels Information:
#
# - image_id: the foreign key
#
# - combinations: one of the target labels
#
# - healthy: one of the target labels
#
# - rust: one of the target labels
#
# - scab: one of the target labels

# %%
print('Loading Test Data Labels from CSV file')
test = pd.read_csv('test.csv')
test.head(3)
# Out:
# Loading Test Data Labels from CSV file
#   image_id
# 0   Test_0
# 1   Test_1
# 2   Test_2

# %%
# Opening single Image 
image_open = Image.open(r'C:\Users\Infinity\Computer Vision Projects\Apple Tree Diseases Predication using Image Classification\images\Train_0.jpg')
plt.imshow(image_open)
plt.title('Image : Train_0')
plt.show()

# %% [markdown]
# ## Data Prepartion

# %% [markdown]
#  **Separating Test and Train data (Based on Labels) into different Folders**

# %% [markdown]
# **We have given input images in single folder.**
# - ***For further model building process we need to separate this data into train and test folders.***
# - ***Separate train data into 4 different folders based on label category.***

# %%
class_labels= train.columns[1:]
print(class_labels)
# Out:
# Index(['healthy', 'multiple_diseases', 'rust', 'scab'], dtype='object')

# %%
# Creating new Label column into train.csv
num = 0
train['label'] =0
for i in class_labels:
    train['label'] = train['label'] + train[i]*num
    num +=1
train.head(5)
# Out:
#   image_id  healthy  multiple_diseases  rust  scab  label
# 0  Train_0        0                  0     0     1      3
# 1  Train_1        0                  1     0     0      1
# 2  Train_2        1                  0     0     0      0
# 3  Train_3        0                  0     1     0      2
# 4  Train_4        1                  0     0     0      0

# %%
# Creating Function to fetch label of individual train image
import re
def get_label(img):
    if re.search('Train',img):
        img = img.split('.')[0] # Fecth image_id from image name
        # return label corresponding to image_id
        label = train.loc[train['image_id'] == img]["label"]
        return label
    elif re.search('Test',img):
        pass

# %%
path__dir =r'C:\Users\Infinity\Computer Vision Projects\Apple Tree Diseases Predication using Image Classification'

# %%
# Creating New folders to separate data
shutil.os.mkdir(path__dir+ r'\train')
shutil.os.mkdir(path__dir+ r'\train\healthy')
shutil.os.mkdir(path__dir+ r'\train\multiple_diseases')
shutil.os.mkdir(path__dir+ r'\train\rust')
shutil.os.mkdir(path__dir+ r'\train\scab')
shutil.os.mkdir(path__dir+ r'\test')

# %%
img ='Train_0.jpg'
img.split("_")[1].split(".")[0]

# %%
# Creating fuction to copy images from original directory to respective folders based on labels
def copy_image_to_its_folder():
    images = natsort.natsorted(os.listdir(dir_path))  # Sorting image in proper form
    for img in tqdm(images):
        label = get_label(img) # getting label of image
        path = os.path.join(dir_path,img) # Original path of image
        
        if search('Train',img): # Searching pattern 'Train' in Image name 
            #label = get_label(img)
            if (img.split("_")[1].split(".")[0]) and label.item() == 0:
                shutil.copy(path,path__dir+ r'\train\healthy' )
            elif (img.split("_")[1].split(".")[0]) and label.item() == 1:
                shutil.copy(path,path__dir+ r'\train\multiple_diseases' )
            elif (img.split("_")[1].split(".")[0]) and label.item() == 2:
                shutil.copy(path,path__dir+ r'\train\rust' )
            elif (img.split("_")[1].split(".")[0]) and label.item() == 3:
                shutil.copy(path,path__dir+ r'\train\scab' )
        elif search('Test',img):
            shutil.copy(path,path__dir+ r'\test')

# %%
data_dir=copy_image_to_its_folder()
# Out:
# 100%|██████████| 3642/3642 [01:03<00:00, 57.19it/s]

# %% [markdown]
# ## Image Preprocessing
# 1. Resizing Image
# 2. Rescaling Image
# 3. Image Augmentation

# %%
Train_dir = path__dir+ r'\train'
Categories = ['healthy','multiple_diseases','rust','scab']
for i in Categories:
    path = os.path.join(Train_dir,i)
    for img in os.listdir(path):
        old_image = cv2.imread(os.path.join(path,img),cv2.COLOR_BGR2RGB)
        new_image=cv2.resize(old_image,(256,256))
        plt.imshow(old_image)
        plt.show()
        break
    break

# %%
new_image=cv2.resize(old_image,(256,256))
plt.imshow(new_image)
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale = 1/255,
                            shear_range = 0.2,
                            zoom_range = 0.2,
                            horizontal_flip = True,
                            vertical_flip = True,
                            validation_split = 0.2)

train_datagen = datagen.flow_from_directory(Train_dir,
                                target_size = (256,256),
                                batch_size =16,
                                class_mode = 'categorical',
                                subset = 'training')
val_datagen = datagen.flow_from_directory(Train_dir,
                                         target_size = (256,256),
                                    batch_size =16,
                                    class_mode = 'categorical',
                                    subset = 'validation')
# Out:
# Found 1458 images belonging to 4 classes.
# Found 363 images belonging to 4 classes.

# %% [markdown]
# ## CNN Model Building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Dense,Activation,Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Dropout,BatchNormalization

# %%
model=Sequential()
model.add(Conv2D(64,(3,3),activation='relu',padding='same',input_shape=(256,256,3)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(4,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 256, 256, 64)      1792
#
#  max_pooling2d_5 (MaxPooling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 64)                524352
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 821,700
# Trainable params: 821,700
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
checkpoint=ModelCheckpoint(r'apple_tree_diseases.h5',
                          monitor='val_loss',
                          mode='min',
                          save_best_only=True,
                          verbose=1)
earlystop=EarlyStopping(monitor='val_loss',
                       min_delta=0.001,
                       patience=10,
                       verbose=1,
                       restore_best_weights=True)

callbacks=[checkpoint,earlystop]

# %%
model_history = model.fit(train_datagen, validation_data=val_datagen,
                          epochs = 30,
                          callbacks =callbacks)
# Out:
# Epoch 1/30
# 92/92 [==============================] - ETA: 0s - loss: 1.2609 - accuracy: 0.3093
# Epoch 1: val_loss improved from inf to 1.25547, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 449s 5s/step - loss: 1.2609 - accuracy: 0.3093 - val_loss: 1.2555 - val_accuracy: 0.3416
# Epoch 2/30
# 92/92 [==============================] - ETA: 0s - loss: 1.2527 - accuracy: 0.3258
# Epoch 2: val_loss improved from 1.25547 to 1.23812, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 344s 4s/step - loss: 1.2527 - accuracy: 0.3258 - val_loss: 1.2381 - val_accuracy: 0.3416
# Epoch 3/30
# 92/92 [==============================] - ETA: 0s - loss: 1.2451 - accuracy: 0.3333
# Epoch 3: val_loss did not improve from 1.23812
# 92/92 [==============================] - 331s 4s/step - loss: 1.2451 - accuracy: 0.3333 - val_loss: 1.2406 - val_accuracy: 0.3416
# Epoch 4/30
# 92/92 [==============================] - ETA: 0s - loss: 1.2212 - accuracy: 0.3621
# Epoch 4: val_loss did not improve from 1.23812
# 92/92 [==============================] - 330s 4s/step - loss: 1.2212 - accuracy: 0.3621 - val_loss: 1.2401 - val_accuracy: 0.3416
# Epoch 5/30
# 92/92 [==============================] - ETA: 0s - loss: 1.1705 - accuracy: 0.4369
# Epoch 5: val_loss improved from 1.23812 to 0.99106, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 331s 4s/step - loss: 1.1705 - accuracy: 0.4369 - val_loss: 0.9911 - val_accuracy: 0.5510
# Epoch 6/30
# 92/92 [==============================] - ETA: 0s - loss: 0.8392 - accuracy: 0.6358
# Epoch 6: val_loss improved from 0.99106 to 0.67125, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 331s 4s/step - loss: 0.8392 - accuracy: 0.6358 - val_loss: 0.6712 - val_accuracy: 0.6970
# Epoch 7/30
# 92/92 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.7106
# Epoch 7: val_loss improved from 0.67125 to 0.61526, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 348s 4s/step - loss: 0.7014 - accuracy: 0.7106 - val_loss: 0.6153 - val_accuracy: 0.7025
# Epoch 8/30
# 92/92 [==============================] - ETA: 0s - loss: 0.6649 - accuracy: 0.7188
# Epoch 8: val_loss did not improve from 0.61526
# 92/92 [==============================] - 336s 4s/step - loss: 0.6649 - accuracy: 0.7188 - val_loss: 0.6234 - val_accuracy: 0.7245
# Epoch 9/30
# 92/92 [==============================] - ETA: 0s - loss: 0.6488 - accuracy: 0.7291
# Epoch 9: val_loss improved from 0.61526 to 0.58122, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 340s 4s/step - loss: 0.6488 - accuracy: 0.7291 - val_loss: 0.5812 - val_accuracy: 0.7603
# Epoch 10/30
# 92/92 [==============================] - ETA: 0s - loss: 0.5628 - accuracy: 0.7675
# Epoch 10: val_loss did not improve from 0.58122
# 92/92 [==============================] - 337s 4s/step - loss: 0.5628 - accuracy: 0.7675 - val_loss: 0.7516 - val_accuracy: 0.6253
# Epoch 11/30
# 92/92 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.7750
# Epoch 11: val_loss improved from 0.58122 to 0.41962, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 330s 4s/step - loss: 0.5381 - accuracy: 0.7750 - val_loss: 0.4196 - val_accuracy: 0.8540
# Epoch 12/30
# 92/92 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.8285
# Epoch 12: val_loss improved from 0.41962 to 0.41170, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 346s 4s/step - loss: 0.4608 - accuracy: 0.8285 - val_loss: 0.4117 - val_accuracy: 0.8430
# Epoch 13/30
# 92/92 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.8491
# Epoch 13: val_loss improved from 0.41170 to 0.37675, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 434s 5s/step - loss: 0.4315 - accuracy: 0.8491 - val_loss: 0.3768 - val_accuracy: 0.8650
# Epoch 14/30
# 92/92 [==============================] - ETA: 0s - loss: 0.4125 - accuracy: 0.8539
# Epoch 14: val_loss improved from 0.37675 to 0.34715, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 392s 4s/step - loss: 0.4125 - accuracy: 0.8539 - val_loss: 0.3472 - val_accuracy: 0.8815
# Epoch 15/30
# 92/92 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.8601
# Epoch 15: val_loss did not improve from 0.34715
# 92/92 [==============================] - 378s 4s/step - loss: 0.3807 - accuracy: 0.8601 - val_loss: 0.3679 - val_accuracy: 0.8595
# Epoch 16/30
# 92/92 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8615
# Epoch 16: val_loss did not improve from 0.34715
# 92/92 [==============================] - 417s 5s/step - loss: 0.3547 - accuracy: 0.8615 - val_loss: 0.3629 - val_accuracy: 0.8650
# Epoch 17/30
# 92/92 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8745
# Epoch 17: val_loss improved from 0.34715 to 0.32382, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 379s 4s/step - loss: 0.3607 - accuracy: 0.8745 - val_loss: 0.3238 - val_accuracy: 0.9036
# Epoch 18/30
# 92/92 [==============================] - ETA: 0s - loss: 0.3234 - accuracy: 0.8786
# Epoch 18: val_loss improved from 0.32382 to 0.31697, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 438s 5s/step - loss: 0.3234 - accuracy: 0.8786 - val_loss: 0.3170 - val_accuracy: 0.9008
# Epoch 19/30
# 92/92 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8759
# Epoch 19: val_loss improved from 0.31697 to 0.29997, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 425s 5s/step - loss: 0.3331 - accuracy: 0.8759 - val_loss: 0.3000 - val_accuracy: 0.8871
# Epoch 20/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2975 - accuracy: 0.8937
# Epoch 20: val_loss did not improve from 0.29997
# 92/92 [==============================] - 403s 4s/step - loss: 0.2975 - accuracy: 0.8937 - val_loss: 0.4364 - val_accuracy: 0.8540
# Epoch 21/30
# 92/92 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.8882
# Epoch 21: val_loss did not improve from 0.29997
# 92/92 [==============================] - 414s 4s/step - loss: 0.3068 - accuracy: 0.8882 - val_loss: 0.3338 - val_accuracy: 0.8843
# Epoch 22/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.8903
# Epoch 22: val_loss improved from 0.29997 to 0.27659, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 523s 6s/step - loss: 0.2953 - accuracy: 0.8903 - val_loss: 0.2766 - val_accuracy: 0.8926
# Epoch 23/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.8951
# Epoch 23: val_loss did not improve from 0.27659
# 92/92 [==============================] - 502s 5s/step - loss: 0.2726 - accuracy: 0.8951 - val_loss: 0.2770 - val_accuracy: 0.8981
# Epoch 24/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.9019
# Epoch 24: val_loss improved from 0.27659 to 0.24390, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 525s 6s/step - loss: 0.2750 - accuracy: 0.9019 - val_loss: 0.2439 - val_accuracy: 0.9146
# Epoch 25/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9040
# Epoch 25: val_loss did not improve from 0.24390
# 92/92 [==============================] - 446s 5s/step - loss: 0.2667 - accuracy: 0.9040 - val_loss: 0.2569 - val_accuracy: 0.9036
# Epoch 26/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2532 - accuracy: 0.9088
# Epoch 26: val_loss improved from 0.24390 to 0.23691, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 414s 4s/step - loss: 0.2532 - accuracy: 0.9088 - val_loss: 0.2369 - val_accuracy: 0.9091
# Epoch 27/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9102
# Epoch 27: val_loss did not improve from 0.23691
# 92/92 [==============================] - 352s 4s/step - loss: 0.2493 - accuracy: 0.9102 - val_loss: 0.2500 - val_accuracy: 0.9229
# Epoch 28/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9218
# Epoch 28: val_loss improved from 0.23691 to 0.22657, saving model to apple_tree_diseases.h5
# 92/92 [==============================] - 358s 4s/step - loss: 0.2236 - accuracy: 0.9218 - val_loss: 0.2266 - val_accuracy: 0.9311
# Epoch 29/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9177
# Epoch 29: val_loss did not improve from 0.22657
# 92/92 [==============================] - 343s 4s/step - loss: 0.2355 - accuracy: 0.9177 - val_loss: 0.2361 - val_accuracy: 0.9174
# Epoch 30/30
# 92/92 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9163
# Epoch 30: val_loss did not improve from 0.22657
# 92/92 [==============================] - 362s 4s/step - loss: 0.2248 - accuracy: 0.9163 - val_loss: 0.2750 - val_accuracy: 0.8981

# %% [markdown]
# ### Plotting Training vs Validation Accuracy

# %%
train_acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
epoachs = range(1,31)
plt.plot(epoachs,train_acc,'g',label='Training Accuracy')
plt.plot(epoachs,val_acc,'b',label='Validation Accuracy')
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
loss_train=model_history.history['loss']
loss_val=model_history.history['val_loss']
epochs=range(1,31)
plt.plot(epochs,loss_train,'g',label='Training Loss')
plt.plot(epochs,loss_val,'b',label='Validation Loss')
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model.save('Apple_Tree_Disease.h5')

# %% [markdown]
# ### Prediction on a Test Image

# %%
test_image=r'C:\Users\Infinity\Computer Vision Projects\Apple Tree Diseases Predication using Image Classification\images\Train_0.jpg'
image_result=Image.open(test_image)

from tensorflow.keras.preprocessing import image
test_image=image.load_img(test_image,target_size=(256,256))
test_image=image.img_to_array(test_image)
test_image=test_image/255
test_image=np.expand_dims(test_image,axis=0)
result=model.predict(test_image)
print(np.argmax(result))
Categories=['healthy','multiple_disease','rust','scab']
image_result=plt.imshow(image_result)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# 3

# %% [markdown]
# #### References :
# - https://www.kaggle.com/competitions/plant-pathology-2020-fgvc7/overview
# - https://bsapubs.onlinelibrary.wiley.com/doi/10.1002/aps3.11390
